# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from finta import TA
import yfinance as yf
# Out:
# 2023-07-20 15:09:14.249088: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define the ticker symbols
#tickerSymbols = ['AAPL', 'AMZN', 'MSFT']

# Initialize a dictionary to hold all dataframes
dict_of_df = {}

#for ticker in tickerSymbols:
# Get data on this ticker
tickerData = yf.Ticker('AAPL')

# Get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', interval='15m', start='2023-6-1', end='2023-7-18')

# %%
tickerDf
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-01 09:30:00-04:00  177.699997  177.865005  176.949997  177.509995
# 2023-06-01 09:45:00-04:00  177.509995  177.690002  176.930603  177.309998
# 2023-06-01 10:00:00-04:00  177.320007  178.250000  177.279999  178.229996
# 2023-06-01 10:15:00-04:00  178.229996  178.360001  177.714996  178.100006
# 2023-06-01 10:30:00-04:00  178.110001  178.990005  178.000000  178.970001
# ...                               ...         ...         ...         ...
# 2023-07-17 14:45:00-04:00  193.649902  193.800003  193.619995  193.678802
# 2023-07-17 15:00:00-04:00  193.679993  193.929993  193.669998  193.804993
# 2023-07-17 15:15:00-04:00  193.800003  194.320007  193.759995  194.149994
# 2023-07-17 15:30:00-04:00  194.139999  194.240005  194.074997  194.139999
# 2023-07-17 15:45:00-04:00  194.130005  194.250000  193.699997  193.979996
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2023-06-01 09:30:00-04:00  4612639        0.0           0.0
# 2023-06-01 09:45:00-04:00  2545624        0.0           0.0
# 2023-06-01 10:00:00-04:00  2342355        0.0           0.0
# 2023-06-01 10:15:00-04:00  2238735        0.0           0.0
# 2023-06-01 10:30:00-04:00  2130895        0.0           0.0
# ...                            ...        ...           ...
# 2023-07-17 14:45:00-04:00   809679        0.0           0.0
# 2023-07-17 15:00:00-04:00  1250414        0.0           0.0
# 2023-07-17 15:15:00-04:00  2449011        0.0           0.0
# 2023-07-17 15:30:00-04:00  1672836        0.0           0.0
# 2023-07-17 15:45:00-04:00  4896889        0.0           0.0
#
# [794 rows x 7 columns]

# %%
tickerDf['14SMA'] = TA.SMA(tickerDf, 14)
tickerDf['14EMA'] = TA.EMA(tickerDf, 14)
tickerDf['7SMA'] = TA.SMA(tickerDf, 7)
tickerDf['7EMA'] = TA.EMA(tickerDf, 7)
tickerDf['RSI'] = TA.RSI(tickerDf)
tickerDf['MACD'] = TA.MACD(tickerDf)['MACD'] - TA.MACD(tickerDf)['SIGNAL']
tickerDf.dropna(inplace=True)

# %%
# Visualize data
tickerDf[['Close', '7SMA', '7EMA']].plot(figsize=(10,4))
plt.grid(True)
plt.title('Close Prices with SMA and EMA')
plt.show()

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(tickerDf.values)

# Split data for LSTM
train_size = int(len(scaled_data) * 0.9)
test_size = len(scaled_data) - train_size

X_train_lstm = scaled_data[:train_size]
X_test_lstm = scaled_data[train_size:]
y_train_lstm = X_train_lstm[:, 0] 
y_test_lstm = X_test_lstm[:, 0]

# Reshape X for LSTM 
X_train_lstm = X_train_lstm.reshape((X_train_lstm.shape[0], 1, X_train_lstm.shape[1]))
X_test_lstm = X_test_lstm.reshape((X_test_lstm.shape[0], 1, X_test_lstm.shape[1]))

# LSTM Model
lstm_model = Sequential()
lstm_model.add(LSTM(50, return_sequences=True, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2]))) 
lstm_model.add(LSTM(50))
lstm_model.add(Dense(1))

lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train_lstm, y_train_lstm, epochs=50)

# Split data for SVR
train_size_svr = int(len(scaled_data) * 0.8)
test_size_svr = len(scaled_data) - train_size_svr

X_train_svr = scaled_data[:train_size_svr]
X_test_svr = scaled_data[train_size_svr:]

y_train_svr = X_train_svr[:, 0]  
y_test_svr = X_test_svr[:, 0]

# Scale data for SVR
scaler_svr = StandardScaler()
X_train_svr = scaler_svr.fit_transform(X_train_svr)
X_test_svr = scaler_svr.transform(X_test_svr)

# SVR Model
svr = SVR(kernel='rbf')
svr.fit(X_train_svr, y_train_svr)

# SVR Evaluation
y_train_pred = svr.predict(X_train_svr)
y_test_pred = svr.predict(X_test_svr)

# Scale prices separately
price_scaler = MinMaxScaler()
price_scaler.fit(tickerDf[['Close']].values)

# Inverse transform predictions
y_train_pred = price_scaler.inverse_transform(y_train_pred.reshape(-1, 1))
y_test_pred = price_scaler.inverse_transform(y_test_pred.reshape(-1, 1))

# Plot results
plt.plot(y_train_lstm, label='Train Actual') 
plt.plot(y_train_pred, label='Train Predicted')
plt.plot(y_test_lstm, label='Test Actual')
plt.plot(y_test_pred, label='Test Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 22/22 [==============================] - 3s 4ms/step - loss: 0.2162
# Epoch 2/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0359
# Epoch 3/50
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 4/50
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 5/50
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 6/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 7/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 8/50
# 22/22 [==============================] - 0s 4ms/step - loss: 8.7497e-04
# Epoch 9/50
# 22/22 [==============================] - 0s 3ms/step - loss: 8.0714e-04
# Epoch 10/50
# 22/22 [==============================] - 0s 3ms/step - loss: 7.5898e-04
# Epoch 11/50
# 22/22 [==============================] - 0s 3ms/step - loss: 7.2369e-04
# Epoch 12/50
# 22/22 [==============================] - 0s 4ms/step - loss: 6.7990e-04
# Epoch 13/50
# 22/22 [==============================] - 0s 4ms/step - loss: 6.3245e-04
# Epoch 14/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.8953e-04
# Epoch 15/50
# 22/22 [==============================] - 0s 3ms/step - loss: 5.5692e-04
# Epoch 16/50
# 22/22 [==============================] - 0s 3ms/step - loss: 5.3316e-04
# Epoch 17/50
# 22/22 [==============================] - 0s 3ms/step - loss: 4.9559e-04
# Epoch 18/50
# 22/22 [==============================] - 0s 3ms/step - loss: 4.5689e-04
# Epoch 19/50
# 22/22 [==============================] - 0s 3ms/step - loss: 4.2747e-04
# Epoch 20/50
# 22/22 [==============================] - 0s 3ms/step - loss: 4.0167e-04
# Epoch 21/50
# 22/22 [==============================] - 0s 3ms/step - loss: 3.8208e-04
# Epoch 22/50
# 22/22 [==============================] - 0s 3ms/step - loss: 3.6102e-04
# Epoch 23/50
# 22/22 [==============================] - 0s 4ms/step - loss: 3.3487e-04
# Epoch 24/50
# 22/22 [==============================] - 0s 4ms/step - loss: 3.1840e-04
# Epoch 25/50
# 22/22 [==============================] - 0s 3ms/step - loss: 3.0206e-04
# Epoch 26/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.9298e-04
# Epoch 27/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.7535e-04
# Epoch 28/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.6692e-04
# Epoch 29/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.5404e-04
# Epoch 30/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.4996e-04
# Epoch 31/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.4077e-04
# Epoch 32/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.3225e-04
# Epoch 33/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.3049e-04
# Epoch 34/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.2340e-04
# Epoch 35/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.1981e-04
# Epoch 36/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.2036e-04
# Epoch 37/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.1087e-04
# Epoch 38/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.1137e-04
# Epoch 39/50
# 22/22 [==============================] - 0s 4ms/step - loss: 2.0702e-04
# Epoch 40/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.0534e-04
# Epoch 41/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.0074e-04
# Epoch 42/50
# 22/22 [==============================] - 0s 4ms/step - loss: 1.9827e-04
# Epoch 43/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.0578e-04
# Epoch 44/50
# 22/22 [==============================] - 0s 3ms/step - loss: 2.0398e-04
# Epoch 45/50
# 22/22 [==============================] - 0s 3ms/step - loss: 1.9781e-04
# Epoch 46/50
# 22/22 [==============================] - 0s 3ms/step - loss: 1.9787e-04
# Epoch 47/50
# 22/22 [==============================] - 0s 3ms/step - loss: 1.9363e-04
# Epoch 48/50
# 22/22 [==============================] - 0s 3ms/step - loss: 1.9068e-04
# Epoch 49/50
# 22/22 [==============================] - 0s 4ms/step - loss: 1.8831e-04
# Epoch 50/50
# 22/22 [==============================] - 0s 4ms/step - loss: 1.8914e-04
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 59
#      56 y_test_pred = price_scaler.inverse_transform(y_test_pred.reshape(-1, 1))
#      58 # Plot results
# ---> 59 plt.plot(y_train, label='Train Actual')
#      60 plt.plot(y_train_pred, label='Train Predicted')
#      61 plt.plot(y_test, label='Test Actual')
#
# NameError: name 'y_train' is not defined

# %%
# Compile and fit the model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 3s 28ms/step - loss: 0.0665
# Epoch 2/20
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0111
# Epoch 3/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0081
# Epoch 4/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0070
# Epoch 5/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0065
# Epoch 6/20
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0052
# Epoch 7/20
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0051
# Epoch 8/20
# 20/20 [==============================] - 1s 27ms/step - loss: 0.0054
# Epoch 9/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0045
# Epoch 10/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0047
# Epoch 11/20
# 20/20 [==============================] - 1s 27ms/step - loss: 0.0040
# Epoch 12/20
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0041
# Epoch 13/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0043
# Epoch 14/20
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0041
# Epoch 15/20
# 20/20 [==============================] - 1s 27ms/step - loss: 0.0037
# Epoch 16/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0038
# Epoch 17/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0040
# Epoch 18/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0043
# Epoch 19/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0042
# Epoch 20/20
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0038

# %%
import math
# Make predictions
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# Create a scaler for 'Close' price only
close_scaler = MinMaxScaler(feature_range=(0, 1))
close_scaler.fit_transform(tickerDf['Close'].values.reshape(-1,1))

# Invert 'Close' price predictions
train_predict_rescaled = close_scaler.inverse_transform(train_predict)
y_train_rescaled = close_scaler.inverse_transform(y_train.reshape(-1,1))
test_predict_rescaled = close_scaler.inverse_transform(test_predict)
y_test_rescaled = close_scaler.inverse_transform(y_test.reshape(-1,1))


# Plotting the prices vs predicted values
plt.figure(figsize=(16,8))

# Training set
plt.subplot(1, 2, 1)
plt.plot(y_train_rescaled, color='blue', label='Real')
plt.plot(train_predict_rescaled[:,0], color='red', label='Predicted')
plt.title('Price Prediction - Training Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()

# Test set
plt.subplot(1, 2, 2)
plt.plot(y_test_rescaled, color='blue', label='Real')
plt.plot(test_predict_rescaled[:,0], color='red', label='Predicted')
plt.title('Price Prediction - Test Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()

plt.show()
# Out:
# 20/20 [==============================] - 0s 11ms/step
# 3/3 [==============================] - 0s 9ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 7
#       4 test_predict = model.predict(x_test)
#       6 # Invert predictions for 'Close' price
# ----> 7 train_predict_rescaled = scaler.inverse_transform(train_predict)
#       8 y_train_rescaled = scaler.inverse_transform(y_train.reshape(-1,1))
#       9 test_predict_rescaled = scaler.inverse_transform(test_predict)
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_data.py:547, in MinMaxScaler.inverse_transform(self, X)
#     541 check_is_fitted(self)
#     543 X = check_array(
#     544     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     545 )
# --> 547 X -= self.min_
#     548 X /= self.scale_
#     549 return X
#
# ValueError: non-broadcastable output operand with shape (619,1) doesn't match the broadcast shape (619,15)
